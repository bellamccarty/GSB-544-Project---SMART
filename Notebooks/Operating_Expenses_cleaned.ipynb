# %% [markdown]
# # OPERATING EXPENSES BY FUNCTION

# %%
import pandas as pd
import numpy as np
from plotnine import *

# %%
data=pd.read_csv('2022_-_2023_NTD_Annual_Data_-_Operating_Expenses__by_Function__20241120.csv')

# %%
data.head()
# Out:
#                       Agency      City State  NTD ID  \
# 0  MTA New York City Transit  Brooklyn    NY   20008
# 1  MTA New York City Transit  Brooklyn    NY   20008
# 2  MTA New York City Transit  Brooklyn    NY   20008
# 3  MTA New York City Transit  Brooklyn    NY   20008
# 4  MTA New York City Transit  Brooklyn    NY   20008
#
#                                    Organization Type  Reporter Type  \
# 0  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 1  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 2  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 3  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 4  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
#
#    Report Year  UACE Code                               UZA Name  \
# 0         2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 1         2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 2         2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 3         2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 4         2023    63217.0  New York--Jersey City--Newark, NY--NJ
#
#    Primary UZA Population  ...  Facility Maintenance  \
# 0              19426449.0  ...            2363284046
# 1              19426449.0  ...             184737190
# 2              19426449.0  ...              13317983
# 3              19426449.0  ...              16870026
# 4              19426449.0  ...               6664701
#
#   Facility Maintenance Questionable General Administration  \
# 0                               NaN             1014596199
# 1                               NaN              589349975
# 2                               NaN              185497525
# 3                               NaN               53827981
# 4                               NaN               21265375
#
#   General Administration Questionable  Reduced Reporter Expenses  \
# 0                                 NaN                          0
# 1                                 NaN                          0
# 2                                 NaN                          0
# 3                                 NaN                          0
# 4                                 NaN                          0
#
#    Reduced Reporter Expenses Questionable       Total  Total Questionable  \
# 0                                     NaN  6047953647                 NaN
# 1                                     NaN  3118485221                 NaN
# 2                                     NaN   564652967                 NaN
# 3                                     NaN   284777119                 NaN
# 4                                     NaN   112504538                 NaN
#
#    Purchased Transportation Reported Separately  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    Purchased Transportation Reported Separately Questionable
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# # Data Description

# %% [markdown]
# 1. **Agency**: The transit agency's name.
#
# 2. **City**: The city in which the agency is headquartered.
#
# 3. **State**: The state in which the agency is headquartered.
#
# 4. **NTD ID**: A five-digit identifying number for each agency used in the current NTD system.
#
# 5. **Organization Type**: Description of the agency's legal entity.
#
# 6. **Reporter Type**: The type of NTD report that the agency completed this year.
#
# 7. **Report Year**: The year for which the data was reported.
#
# 8. **UACE Code**: The UACE code remains consistent across census years.
#
# 9. **UZA Name**: The name of an agency's Urbanized Area.
#
# 10. **primary_uza_population**: The population of the urbanized area primarily served by the agency.
#
# 11. **Agency VOMS**: The number of revenue vehicles operated across the whole agency to meet the annual maximum service requirement. This is the revenue vehicle count during the peak season of the year, excluding atypical days and one-time special events.
#
# 12. **Mode**: A system for carrying transit passengers described by specific right-of-way (ROW), technology, and operational features.
#
# 13. **Mode Name**: Detailed description of the system used for carrying transit passengers.
#
# 14. **Type of Service**: Describes how public transportation services are provided by the transit agency: directly operated (DO) or purchased transportation (PT) services.
#
# 15. **Mode VOMS**: The number of revenue vehicles operated by the given mode and type of service to meet the annual maximum service requirement.
#
# 16. **Vehicle Operations**: The Vehicle Operations function includes wages, salaries, and expenses related to dispatching and running vehicles, including administrative support.
#
# 17. **Vehicle Operations Questionable**: FTA marks a data point as Questionable when there is reason to believe it is incorrect, but the reporting agency has been unable to correct the data or offer an explanation.
#
# 18. **Vehicle Maintenance**: The Vehicle Maintenance function includes wages, salaries, and expenses incurred during activities related to keeping vehicles operational and in good repair.
#
# 19. **Vehicle Maintenance Questionable**: FTA marks a data point as Questionable when there is reason to believe it is incorrect, but the reporting agency has been unable to correct the data or offer an explanation.
#
# 20. **Facility Maintenance**: The Facility Maintenance function includes all activities related to keeping buildings, structures, and other non-vehicle assets operational and in good repair.
#
# 21. **Facility Maintenance Questionable**: FTA marks a data point as Questionable when there is reason to believe it is incorrect, but the reporting agency has been unable to correct the data or offer an explanation.
#
# 22. **General Administration**: The General Administration function includes wages, salaries, and expenses incurred to perform support and administrative activities.
#
# 23. **General Administration Questionable**: FTA marks a data point as Questionable when there is reason to believe it is incorrect, but the reporting agency has been unable to correct the data or offer an explanation.
# 24. **Reduced Reporter Expenses**: Reduced Reporters and Rural Reporters report only the total operating expenses by mode and type of service without categorizing them further.
#
# 25. **Reduced Reporter Expenses Questionable**: FTA marks a data point as Questionable when there is reason to believe it is incorrect, but the reporting agency has been unable to correct the data or offer an explanation.
# 26. **Total**: The total of the operating expenses reported in previous columns. Does not include Purchased Transportation Reported Separately.
#
# 27. **Total Questionable**: FTA marks a data point as Questionable when there is reason to believe it is incorrect, but the reporting agency has been unable to correct the data or offer an explanation.
#
# 28. **Purchased Transportation Reported Separately**: Payments or accruals to sellers/providers of services excluded from the Total column to avoid double counting.
#
# 29. **Purchased Transportation Reported Separately Questionable**: FTA marks a data point as Questionable when there is reason to believe it is incorrect, but the reporting agency has been unable to correct the data or offer an explanation.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 29 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Agency                                                     132 non-null    object
#  1   City                                                       132 non-null    object
#  2   State                                                      132 non-null    object
#  3   NTD ID                                                     132 non-null    int64
#  4   Organization Type                                          132 non-null    object
#  5   Reporter Type                                              132 non-null    object
#  6   Report Year                                                132 non-null    int64
#  7   UACE Code                                                  78 non-null     float64
#  8   UZA Name                                                   78 non-null     object
#  9   Primary UZA Population                                     78 non-null     float64
#  10  Agency VOMS                                                132 non-null    int64
#  11  Mode                                                       132 non-null    object
#  12  Mode Name                                                  132 non-null    object
#  13  TOS                                                        132 non-null    object
#  14  Mode VOMS                                                  132 non-null    int64
#  15  Vehicle Operations                                         132 non-null    int64
#  16  Vehicle Operations Questionable                            0 non-null      float64
#  17  Vehicle Maintenance                                        132 non-null    int64
#  18  Vehicle Maintenance Questionable                           0 non-null      float64
#  19  Facility Maintenance                                       132 non-null    int64
#  20  Facility Maintenance Questionable                          0 non-null      float64
#  21  General Administration                                     132 non-null    int64
#  22  General Administration Questionable                        0 non-null      float64
#  23  Reduced Reporter Expenses                                  132 non-null    int64
#  24  Reduced Reporter Expenses Questionable                     0 non-null      float64
#  25  Total                                                      132 non-null    int64
#  26  Total Questionable                                         0 non-null      float64
#  27  Purchased Transportation Reported Separately               132 non-null    int64
#  28  Purchased Transportation Reported Separately Questionable  0 non-null      float64
# dtypes: float64(9), int64(11), object(9)
# memory usage: 30.0+ KB

# %%
import pandas as pd

# Assuming `df` is your DataFrame
data.columns = data.columns.str.replace(' ', '_')

# Display the updated column names
print(data.columns)
# Out:
# Index(['Agency', 'City', 'State', 'NTD_ID', 'Organization_Type',
#        'Reporter_Type', 'Report_Year', 'UACE_Code', 'UZA_Name',
#        'Primary_UZA_Population', 'Agency_VOMS', 'Mode', 'Mode_Name', 'TOS',
#        'Mode_VOMS', 'Vehicle_Operations', 'Vehicle_Operations_Questionable',
#        'Vehicle_Maintenance', 'Vehicle_Maintenance_Questionable',
#        'Facility_Maintenance', 'Facility_Maintenance_Questionable',
#        'General_Administration', 'General_Administration_Questionable',
#        'Reduced_Reporter_Expenses', 'Reduced_Reporter_Expenses_Questionable',
#        'Total', 'Total_Questionable',
#        'Purchased_Transportation_Reported_Separately',
#        'Purchased_Transportation_Reported_Separately_Questionable'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Agency                                                         0
# City                                                           0
# State                                                          0
# NTD_ID                                                         0
# Organization_Type                                              0
# Reporter_Type                                                  0
# Report_Year                                                    0
# UACE_Code                                                     54
# UZA_Name                                                      54
# Primary_UZA_Population                                        54
# Agency_VOMS                                                    0
# Mode                                                           0
# Mode_Name                                                      0
# TOS                                                            0
# Mode_VOMS                                                      0
# Vehicle_Operations                                             0
# Vehicle_Operations_Questionable                              132
# Vehicle_Maintenance                                            0
# Vehicle_Maintenance_Questionable                             132
# Facility_Maintenance                                           0
# Facility_Maintenance_Questionable                            132
# General_Administration                                         0
# General_Administration_Questionable                          132
# Reduced_Reporter_Expenses                                      0
# Reduced_Reporter_Expenses_Questionable                       132
# Total                                                          0
# Total_Questionable                                           132
# Purchased_Transportation_Reported_Separately                   0
# Purchased_Transportation_Reported_Separately_Questionable    132
# dtype: int64

# %%
data['Mode_Name']
# Out:
# 0             Heavy Rail
# 1                    Bus
# 2        Demand Response
# 3           Commuter Bus
# 4      Bus Rapid Transit
#              ...
# 127                  Bus
# 128                  Bus
# 129         Commuter Bus
# 130      Demand Response
# 131                  Bus
# Name: Mode_Name, Length: 132, dtype: object

# %%
data = data.drop(columns=[col for col in data.columns if "_1" in col or "Questionable" in col])

# %%
data.isnull().sum()
# Out:
# Agency                                           0
# City                                             0
# State                                            0
# NTD_ID                                           0
# Organization_Type                                0
# Reporter_Type                                    0
# Report_Year                                      0
# UACE_Code                                       54
# UZA_Name                                        54
# Primary_UZA_Population                          54
# Agency_VOMS                                      0
# Mode                                             0
# Mode_Name                                        0
# TOS                                              0
# Mode_VOMS                                        0
# Vehicle_Operations                               0
# Vehicle_Maintenance                              0
# Facility_Maintenance                             0
# General_Administration                           0
# Reduced_Reporter_Expenses                        0
# Total                                            0
# Purchased_Transportation_Reported_Separately     0
# dtype: int64

# %%
data.to_csv('/Users/snehanarayanan/Downloads/data_cleaned_operating_expenses.csv', index=False)

# %% [markdown]
# # EDA

# %% [markdown]
# ## 1.Total Expenses by Mode

# %%
total_expenses_by_mode = data.groupby('Mode_Name').agg({'Total': 'sum'}).reset_index()

# %%
print(top_expenses_by_mode.columns)
# Out:
# Index(['mode_name', 'total'], dtype='object')

# %%
top_expenses_by_mode = total_expenses_by_mode.sort_values(by="Total", ascending=False).head(17)

# %%
plot1 = (
    ggplot(top_expenses_by_mode, aes(x="Mode_Name", y="Total")) +
    geom_bar(stat="identity", fill="coral") +
    labs(title="Top 17 Most Expensive Modes by Total Operating Expenses", 
         x="Mode", y="Total Expenses ($)") +
    theme_minimal() +
    theme(axis_text_x=element_text(angle=45, hjust=1))  
)

plot1.show()

# %% [markdown]
# ## 2.Population vs Total Expenses

# %%
top_20_data = data.sort_values("Total", ascending=False).head(20)

plot2 = (
    ggplot(top_20_data, aes(x="Primary_UZA_Population", y="Total", color="City")) +
    geom_point(alpha=0.6) +
    geom_smooth(method="lm", color="red", se=False) +
    labs(
        title="Top 20 Cities: Population vs Total Expenses", 
        x="Population", 
        y="Total Expenses ($)", 
        color="City"
    ) +
    theme_minimal()
)

plot2.show()

# %%
top_20_data.sort_values(by="Total", ascending=False)
# Out:
#                                                 Agency           City State  \
# 0                            MTA New York City Transit       Brooklyn    NY
# 1                            MTA New York City Transit       Brooklyn    NY
# 9                            MTA Long Island Rail Road       New York    NY
# 5    Metro-North Commuter Railroad Company, dba: MT...       New York    NY
# 8                                      MTA Bus Company       New York    NY
# 2                            MTA New York City Transit       Brooklyn    NY
# 20             Port Authority Trans-Hudson Corporation       New York    NY
# 3                            MTA New York City Transit       Brooklyn    NY
# 10   Westchester County, dba: Westchester County - ...   White Plains    NY
# 119         New York City Department of Transportation       New York    NY
# 18   County of Nassau, dba: Nassau Inter County Exp...        Mineola    NY
# 4                            MTA New York City Transit       Brooklyn    NY
# 21   Niagara Frontier Transportation Authority, dba...        Buffalo    NY
# 13           Capital District Transportation Authority         Albany    NY
# 26                            Regional Transit Service      Rochester    NY
# 41   Staten Island Rapid Transit Operating Authorit...  Staten Island    NY
# 46      New York City Economic Development Corporation       New York    NY
# 29   Central New York Regional Transportation Autho...       Syracuse    NY
# 25        Suffolk County , dba: Suffolk County Transit        Yaphank    NY
# 24        Suffolk County , dba: Suffolk County Transit        Yaphank    NY
#
#      NTD_ID                                  Organization_Type  Reporter_Type  \
# 0     20008  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 1     20008  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 9     20100  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 5     20078  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 8     20188  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 2     20008  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 20    20098  Independent Public Agency or Authority of Tran...  Full Reporter
# 3     20008  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 10    20076  City, County or Local Government Unit or Depar...  Full Reporter
# 119   20082  City, County or Local Government Unit or Depar...  Full Reporter
# 18    20206  City, County or Local Government Unit or Depar...  Full Reporter
# 4     20008  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 21    20004  Independent Public Agency or Authority of Tran...  Full Reporter
# 13    20002  Independent Public Agency or Authority of Tran...  Full Reporter
# 26    20113  Independent Public Agency or Authority of Tran...  Full Reporter
# 41    20099  Subsidiary Unit of a Transit Agency, Reporting...  Full Reporter
# 46    22930                     Private-Non-Profit Corporation  Full Reporter
# 29    20018  Independent Public Agency or Authority of Tran...  Full Reporter
# 25    20072  City, County or Local Government Unit or Depar...  Full Reporter
# 24    20072  City, County or Local Government Unit or Depar...  Full Reporter
#
#      Report_Year  UACE_Code                               UZA_Name  \
# 0           2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 1           2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 9           2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 5           2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 8           2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 2           2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 20          2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 3           2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 10          2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 119         2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 18          2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 4           2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 21          2023    11350.0                            Buffalo, NY
# 13          2023      970.0                Albany--Schenectady, NY
# 26          2023    75664.0                          Rochester, NY
# 41          2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 46          2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 29          2023    86302.0                           Syracuse, NY
# 25          2023    63217.0  New York--Jersey City--Newark, NY--NJ
# 24          2023    63217.0  New York--Jersey City--Newark, NY--NJ
#
#      Primary_UZA_Population  ...          Mode_Name TOS Mode_VOMS  \
# 0                19426449.0  ...         Heavy Rail  DO      5384
# 1                19426449.0  ...                Bus  DO      3214
# 9                19426449.0  ...      Commuter Rail  DO      1109
# 5                19426449.0  ...      Commuter Rail  DO      1132
# 8                19426449.0  ...                Bus  DO      1134
# 2                19426449.0  ...    Demand Response  PT       876
# 20               19426449.0  ...         Heavy Rail  DO       288
# 3                19426449.0  ...       Commuter Bus  DO       443
# 10               19426449.0  ...                Bus  PT       268
# 119              19426449.0  ...          Ferryboat  DO         4
# 18               19426449.0  ...                Bus  PT       235
# 4                19426449.0  ...  Bus Rapid Transit  DO       123
# 21                 948864.0  ...                Bus  DO       197
# 13                 593142.0  ...                Bus  DO       214
# 26                 704327.0  ...                Bus  DO       163
# 41               19426449.0  ...         Heavy Rail  DO        44
# 46               19426449.0  ...          Ferryboat  PT        25
# 29                 413660.0  ...                Bus  DO       131
# 25               19426449.0  ...                Bus  PT       124
# 24               19426449.0  ...    Demand Response  PT       141
#
#     Vehicle_Operations  Vehicle_Maintenance  Facility_Maintenance  \
# 0           1624084504           1045988898            2363284046
# 1           1835649901            508748155             184737190
# 9            774294835            517414685             515194360
# 5            634927308            308416874             382895348
# 8            528161421            211902424              12419056
# 2            336859361             28978098              13317983
# 20           183352477             62262343             120976548
# 3            167620712             46458400              16870026
# 10            58155022             19499849               4474860
# 119          100342395             28466729              13242013
# 18            74320925             21310112               4047767
# 4             66220527             18353935               6664701
# 21            60134717             25158835               4738667
# 13            55925498             12470471               7195362
# 26            40760510             16324060               5889377
# 41            24383434              7205633              25984983
# 46            33555017              9580494               5614641
# 29            35019606             16045024               5418703
# 25            33087677              9997644               2707232
# 24            26479603              3479748               2063953
#
#      General_Administration  Reduced_Reporter_Expenses       Total  \
# 0                1014596199                          0  6047953647
# 1                 589349975                          0  3118485221
# 9                 328314820                          0  2135218700
# 5                 279853503                          0  1606093033
# 8                 159246105                          0   911729006
# 2                 185497525                          0   564652967
# 20                185664157                          0   552255525
# 3                  53827981                          0   284777119
# 10                 84664116                          0   166793847
# 119                11760529                          0   153811666
# 18                 35740094                          0   135418898
# 4                  21265375                          0   112504538
# 21                 15097763                          0   105129982
# 13                 14293863                          0    89885194
# 26                 16077165                          0    79051112
# 41                 12837210                          0    70411260
# 46                 20379962                          0    69130114
# 29                 11339877                          0    67823210
# 25                 11470269                          0    57262822
# 24                  5229659                          0    37252963
#
#      Purchased_Transportation_Reported_Separately
# 0                                               0
# 1                                               0
# 9                                               0
# 5                                               0
# 8                                               0
# 2                                               0
# 20                                              0
# 3                                               0
# 10                                              0
# 119                                             0
# 18                                              0
# 4                                               0
# 21                                              0
# 13                                              0
# 26                                              0
# 41                                              0
# 46                                              0
# 29                                              0
# 25                                              0
# 24                                              0
#
# [20 rows x 22 columns]

# %% [markdown]
# ## 4.Total Expenses by Type of Service

# %%
total_expenses_by_service = data.groupby("TOS")["Total"].sum().reset_index()

plot4 = (
    ggplot(total_expenses_by_service, aes(x="TOS", y="Total", fill="TOS")) +
    geom_bar(stat="identity") +
    labs(
        title="Total Expenses by Type of Service",
        x="Type of Service",
        y="Total Expenses ($)",
        fill="Type of Service"
    ) +
    theme_minimal()
)


plot4.show()

# %% [markdown]
# # Correlation Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numeric_data = data.select_dtypes(include=[np.number])

correlation_matrix = numeric_data.corr()

plt.figure(figsize=(10, 8))  
sns.heatmap(
    correlation_matrix,
    annot=True, 
    fmt=".2f",   
    cmap="coolwarm",  
    cbar=True,   
    square=True, 
    linewidths=0.5,  
)
plt.title("Correlation Heatmap", fontsize=16)
plt.xticks(rotation=45, ha="right", fontsize=10)  
plt.yticks(fontsize=10)  
plt.tight_layout() 
plt.show()
